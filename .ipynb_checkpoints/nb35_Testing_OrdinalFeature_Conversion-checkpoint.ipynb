# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
#import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline

from importlib import reload
from matplotlib import cm
from imblearn.under_sampling import TomekLinks, RandomUnderSampler
from imblearn.over_sampling import SMOTE

from sklearn.model_selection import train_test_split
from sklearn.metrics import (make_scorer, roc_auc_score, 
                             classification_report, 
                             precision_recall_curve,
                             roc_curve)
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KernelDensity
#from xgboost import XGBClassifier

from feature_processing import (create_contingency_table,
                                calculate_conditional_prob_bin,
                                encode_my_categorical_labels,
                                calculate_conditional_prob_cat,
                                estimate_cond_prob_density,
                                bin_myFeature)
import feature_analysis as fa
import porto_seguro as ps

import warnings
warnings.simplefilter("ignore", category=PendingDeprecationWarning)
warnings.simplefilter("ignore", category=DeprecationWarning)

# %%
train = pd.read_csv('train.csv', header=0)

all_fs = train.columns[2:]
binary_fs = sorted([f for f in all_fs if '_bin' in f])
categorical_fs = sorted([f for f in all_fs if '_cat' in f])
other_fs = sorted([f for f in all_fs
            if f not in binary_fs
            if f not in categorical_fs])

binaries = train[binary_fs]
categoricals = ps.fuseCategoricalFeatures(train[categorical_fs])
cont_ordinals = train[other_fs]
target = train.target

train.shape, binaries.shape, categoricals.shape, cont_ordinals.shape
# Out:
# ((595212, 59), (595212, 17), (595212, 14), (595212, 26))

# %%
# Baseline bulk frequency of Class1
class1_freq = np.sum(target)/len(target)
class1_freq
# Out:
# 0.036447517859182946

# %%
cont_ordinals.columns
# Out:
# Index(['ps_calc_01', 'ps_calc_02', 'ps_calc_03', 'ps_calc_04', 'ps_calc_05',
#        'ps_calc_06', 'ps_calc_07', 'ps_calc_08', 'ps_calc_09', 'ps_calc_10',
#        'ps_calc_11', 'ps_calc_12', 'ps_calc_13', 'ps_calc_14', 'ps_car_11',
#        'ps_car_12', 'ps_car_13', 'ps_car_14', 'ps_car_15', 'ps_ind_01',
#        'ps_ind_03', 'ps_ind_14', 'ps_ind_15', 'ps_reg_01', 'ps_reg_02',
#        'ps_reg_03'],
#       dtype='object')

# %%
test = cont_ordinals.loc[:, ['ps_reg_01', 'ps_ind_03']]

# %%
test_converted = ps.convertOrdinalFeatures(test, target)

# %%
test_converted.head(5)
# Out:
#    ps_reg_01  ps_ind_03
# 0   5.618879   4.912834
# 1   6.454873  13.328299
# 2   4.280513  -0.416073
# 3  12.750362 -15.617174
# 4   5.618879  46.084586

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
ax1.scatter(test.iloc[:, 0], test_converted.iloc[:, 0])
ax1.set_title('ps_reg_01')
ax2.scatter(test.iloc[:, 1], test_converted.iloc[:, 1])
ax2.set_title('ps_reg_02')
ax3.scatter(test.iloc[:, 0], test_converted.iloc[:, 0], s=20, color='skyblue', alpha=0.3, label='ps_reg_01')
ax3.scatter(test.iloc[:, 1], test_converted.iloc[:, 1], s=20, color='yellowgreen', alpha=0.3, label='ps_reg_02')
ax3.set_title('Comparison')

# %% [markdown]
# The graphs look proper in comparison to the KDE plots in nb34 for each feature. Now I can convert the entire feature space in one shot!

# %% [markdown]
# ## See how long it takes to convert all features (initially done on i5 MacBook Pro)

# %%
reload(ps)
# Out:
# <module 'porto_seguro' from '/Users/ryohayama/python/porto_seguro/porto_seguro.py'>

# %%
# %%time
converted = ps.convertOrdinalFeatures(cont_ordinals, target, verbose=True)
# Out:
# Processing ps_calc_01
# Processing ps_calc_02
# Processing ps_calc_03
# Processing ps_calc_04
# Processing ps_calc_05
# Processing ps_calc_06
# Processing ps_calc_07
# Processing ps_calc_08
# Processing ps_calc_09
# Processing ps_calc_10
# Processing ps_calc_11
# Processing ps_calc_12
# Processing ps_calc_13
# Processing ps_calc_14
# Processing ps_car_11
# Processing ps_car_12
# Processing ps_car_13
# Processing ps_car_14
# Processing ps_car_15
# Processing ps_ind_01
# Processing ps_ind_03
# Processing ps_ind_14
# Processing ps_ind_15
# Processing ps_reg_01
# Processing ps_reg_02
# Processing ps_reg_03
# CPU times: user 5min 9s, sys: 27 s, total: 5min 36s
# Wall time: 5min 43s

# %%
converted.head(10)
# Out:
#    ps_calc_01  ps_calc_02  ps_calc_03  ps_calc_04  ps_calc_05  ps_calc_06  \
# 0    0.033157    0.564815    0.333015   -0.574689   -0.085642   -1.623085
# 1    0.706844   -1.485546    1.335881    1.007697   -0.085642   -0.557878
# 2    2.028335    0.681293   -1.762433    1.007697    0.415898   -0.557878
# 3    0.033157   -0.664123   -1.762433    1.007697    0.465238   -1.143279
# 4    1.629041    1.263912   -3.269787    1.007697    0.415898   -0.232915
# 5    0.429577    0.385702    1.096627   -0.574689   -0.085642    1.965574
# 6   -1.212545    1.263912    0.566912    1.007697    0.415898    1.965574
# 7   -2.736168    0.564815   -1.762433   -0.149528    0.415898   -1.143279
# 8    1.308819    0.385702   -0.286944   -0.574689   -0.085642   -1.143279
# 9    0.429577    0.385702    1.501779    1.007697    0.415898    1.965574
#
#    ps_calc_07  ps_calc_08  ps_calc_09  ps_calc_10    ...      ps_car_13  \
# 0    2.068504   -1.074326   -1.853818   -1.431269    ...       4.628532
# 1   -2.449961    1.800915   -1.853818    0.068171    ...     -19.641741
# 2    2.068504    1.800915    0.739046    0.068171    ...     -17.863191
# 3    2.068504    1.800915    1.197985   -0.792381    ...     -24.822424
# 4   -1.217631   -1.074326    0.739046   -1.732901    ...     -23.121694
# 5   -0.166591   -1.074326    0.435495   -0.606935    ...       4.628532
# 6    2.068504    1.800915    0.435495    1.348883    ...     -17.863191
# 7    2.068504    1.904735   -1.853818   -3.096056    ...       6.502805
# 8   -1.217631   -0.747275    1.197985   -1.351896    ...      -6.535568
# 9   -0.166591   -0.747275   -1.853818   -1.351896    ...      79.416048
#
#    ps_car_14  ps_car_15  ps_ind_01  ps_ind_03  ps_ind_14  ps_ind_15  \
# 0  -6.272029  14.167378   0.700330   4.912834   -0.40156 -13.986257
# 1  -5.772784 -18.467825  -7.541982  13.328299   -0.40156   8.373485
# 2  -5.191723   6.825735  11.143586  -0.416073   -0.40156 -15.828742
# 3   0.768756 -26.289161  -8.805029 -15.617174   -0.40156  -1.024461
# 4  -6.240336 -26.289161  -8.805029  46.084586   -0.40156 -11.305308
# 5  -3.782870  -4.311472  11.143586  -8.288965   -0.40156   8.861248
# 6  -6.272029   1.184726   0.700330 -17.918591   -0.40156  -1.024461
# 7  -6.241126   6.825735  11.143586  -8.288965   -0.40156 -15.416979
# 8  -3.782870  -9.692951  11.143586 -17.918591   -0.40156   8.861248
# 9  -5.493206  14.167378  -7.541982 -15.617174   -0.40156   6.996167
#
#    ps_reg_01  ps_reg_02  ps_reg_03
# 0   5.618879 -17.470081  -4.559999
# 1   6.454873  -1.364078  -1.632219
# 2   4.280513 -11.414774 -22.098194
# 3  12.750362 -17.470081 -10.900253
# 4   5.618879  14.933445   3.407406
# 5  12.750362  68.384974  60.718094
# 6  -1.068751 -17.823418  -9.615246
# 7   5.618879  -1.364078 -10.055611
# 8  12.750362  17.708378   7.253213
# 9  12.750362  31.615542  60.588480
#
# [10 rows x 26 columns]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
X = np.array(converted)
y = np.array(target)

Xpca = pca.fit_transform(X)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
ax1.scatter(Xpca[:, 0], Xpca[:, 1], c=y, cmap=cm.bwr, alpha=0.2)
ax2.scatter(Xpca[:, 0], Xpca[:, 2], c=y, cmap=cm.bwr, alpha=0.2)
ax3.scatter(Xpca[:, 0], Xpca[:, 3], c=y, cmap=cm.bwr, alpha=0.2)

# %%
new_categoricals = ps.fuseCategoricalFeatures(categoricals)
bincats = pd.concat([binaries, new_categoricals], axis=1)

# %%
bincat2probas = {}
for i, f in enumerate(bincats.columns):
    fvt = fa.FeatureVsTarget(bincats[f], target)
    bincat2probas[f] = (100*(fvt.calculate_deviation(mode='ratio')[0] - 1)[1]).to_dict()
    
bincat_converted = pd.DataFrame()
for i, f in enumerate(bincats.columns):
    bincat_converted[f] = bincats[f].replace(bincat2probas[f])

# %%
converted_all = pd.concat([bincat_converted, converted], axis=1)

# %%
pca1 = PCA()
X1 = np.array(converted_all)
y = np.array(target)

Xpca1 = pca1.fit_transform(X1)

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(15, 3))
ax1.scatter(Xpca1[:, 0], Xpca1[:, 1], c=y, cmap=cm.bwr, alpha=0.15)
ax2.scatter(Xpca1[:, 1], Xpca1[:, 2], c=y, cmap=cm.bwr, alpha=0.15)
ax3.scatter(Xpca1[:, 2], Xpca1[:, 3], c=y, cmap=cm.bwr, alpha=0.15)
ax4.scatter(Xpca1[:, 3], Xpca1[:, 4], c=y, cmap=cm.bwr, alpha=0.15)
ax5.scatter(Xpca1[:, 4], Xpca1[:, 5], c=y, cmap=cm.bwr, alpha=0.15)
plt.tight_layout()
