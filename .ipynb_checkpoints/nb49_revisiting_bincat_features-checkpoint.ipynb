# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline

from collections import namedtuple
from importlib import reload
from matplotlib import cm
from imblearn.under_sampling import TomekLinks, RandomUnderSampler
from imblearn.over_sampling import SMOTE

from sklearn.model_selection import train_test_split
from sklearn.metrics import (make_scorer, roc_auc_score, 
                             classification_report, 
                             precision_recall_curve,
                             roc_curve)
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

from xgboost import XGBClassifier

import warnings
warnings.simplefilter("ignore", category=PendingDeprecationWarning)
warnings.simplefilter("ignore", category=DeprecationWarning)
# Out:
# /home/ryohayama/.local/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import sys
sys.path.append('/home/ryohayama/python_current/BasicFeatureAnalysis')

import feature as F
import feature_collection as FC

# %%
import ps.joint_probability as psjp

# %%
train = pd.read_csv('train.csv', header=0)

all_fs = train.columns[2:]

binary_fs = sorted([f for f in all_fs if '_bin' in f])

categorical_fs = sorted([f for f in all_fs if '_cat' in f])

other_fs = sorted([f for f in all_fs
                if f not in binary_fs
                if f not in categorical_fs])

target = train.target

# %%
train.columns
# Out:
# Index(['id', 'target', 'ps_ind_01', 'ps_ind_02_cat', 'ps_ind_03',
#        'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_ind_06_bin', 'ps_ind_07_bin',
#        'ps_ind_08_bin', 'ps_ind_09_bin', 'ps_ind_10_bin', 'ps_ind_11_bin',
#        'ps_ind_12_bin', 'ps_ind_13_bin', 'ps_ind_14', 'ps_ind_15',
#        'ps_ind_16_bin', 'ps_ind_17_bin', 'ps_ind_18_bin', 'ps_reg_01',
#        'ps_reg_02', 'ps_reg_03', 'ps_car_01_cat', 'ps_car_02_cat',
#        'ps_car_03_cat', 'ps_car_04_cat', 'ps_car_05_cat', 'ps_car_06_cat',
#        'ps_car_07_cat', 'ps_car_08_cat', 'ps_car_09_cat', 'ps_car_10_cat',
#        'ps_car_11_cat', 'ps_car_11', 'ps_car_12', 'ps_car_13', 'ps_car_14',
#        'ps_car_15', 'ps_calc_01', 'ps_calc_02', 'ps_calc_03', 'ps_calc_04',
#        'ps_calc_05', 'ps_calc_06', 'ps_calc_07', 'ps_calc_08', 'ps_calc_09',
#        'ps_calc_10', 'ps_calc_11', 'ps_calc_12', 'ps_calc_13', 'ps_calc_14',
#        'ps_calc_15_bin', 'ps_calc_16_bin', 'ps_calc_17_bin', 'ps_calc_18_bin',
# ...

# %% [markdown]
# # Focus on select feature from combinatorial selection

# %% [markdown]
# ## inds

# %%
# ind_bins
ind_bins_fs = [f for f in all_fs 
               if '_bin' in f
               if '_ind' in f]
ind_bins_fs = ind_bins_fs.copy()
ind_bins_fs.remove('ps_ind_08_bin')
ind_bins_fs.remove('ps_ind_09_bin')

ind_bins = train[ind_bins_fs]

ind_cat_fs = [f for f in categorical_fs if 'ind' in f]
ind_cat = train[ind_cat_fs] + 1

inds = pd.concat([ind_bins, ind_cat], axis=1)

# %%
inds.columns
# Out:
# Index(['ps_ind_06_bin', 'ps_ind_07_bin', 'ps_ind_10_bin', 'ps_ind_11_bin',
#        'ps_ind_12_bin', 'ps_ind_13_bin', 'ps_ind_16_bin', 'ps_ind_17_bin',
#        'ps_ind_18_bin', 'ps_ind_02_cat', 'ps_ind_04_cat', 'ps_ind_05_cat'],
#       dtype='object')

# %%
inds.head()
# Out:
#    ps_ind_06_bin  ps_ind_07_bin  ps_ind_10_bin  ps_ind_11_bin  ps_ind_12_bin  \
# 0              0              1              0              0              0
# 1              0              0              0              0              0
# 2              0              0              0              0              0
# 3              1              0              0              0              0
# 4              1              0              0              0              0
#
#    ps_ind_13_bin  ps_ind_16_bin  ps_ind_17_bin  ps_ind_18_bin  ps_ind_02_cat  \
# 0              0              0              1              0              3
# 1              0              0              0              1              2
# 2              0              1              0              0              5
# 3              0              1              0              0              2
# 4              0              1              0              0              3
#
#    ps_ind_04_cat  ps_ind_05_cat
# ...

# %%
ind_collection = FC.CategoricalFeatureCollection(inds, target=target)
ind_proba = ind_collection.convert2CondProba()

# %%
ind_proba
# Out:
#         ps_ind_06_bin  ps_ind_07_bin  ps_ind_10_bin  ps_ind_11_bin  \
# 0            0.041585       0.047350       0.036441       0.036432
# 1            0.041585       0.032676       0.036441       0.036432
# 2            0.041585       0.032676       0.036441       0.036432
# 3            0.028537       0.032676       0.036441       0.036432
# 4            0.028537       0.032676       0.036441       0.036432
# 5            0.041585       0.032676       0.036441       0.036432
# 6            0.041585       0.047350       0.036441       0.036432
# 7            0.028537       0.032676       0.036441       0.036432
# 8            0.041585       0.032676       0.036441       0.036432
# 9            0.041585       0.047350       0.036441       0.036432
# 10           0.041585       0.032676       0.036441       0.036432
# 11           0.041585       0.047350       0.036441       0.036432
# 12           0.041585       0.032676       0.036441       0.036432
# ...

# %% [markdown]
# ## cars

# %%
# car_cats
car_cats_fs = [f for f in categorical_fs if 'car' in f]
car_cats = train[car_cats_fs] + 1

# car_cats subsets. I may or may not use subsets
car_cat_small_fs = ['ps_car_02_cat', 'ps_car_03_cat', 'ps_car_05_cat', 'ps_car_07_cat',
                     'ps_car_08_cat', 'ps_car_09_cat', 'ps_car_10_cat']
car_cat_big_fs = [f for f in car_cats if f not in car_cat_small_fs]

car_cat_small = car_cats[car_cat_small_fs]
car_cat_big = car_cats[car_cat_big_fs]

car_cats.columns
# Out:
# Index(['ps_car_01_cat', 'ps_car_02_cat', 'ps_car_03_cat', 'ps_car_04_cat',
#        'ps_car_05_cat', 'ps_car_06_cat', 'ps_car_07_cat', 'ps_car_08_cat',
#        'ps_car_09_cat', 'ps_car_10_cat', 'ps_car_11_cat'],
#       dtype='object')

# %%
car_collection = FC.CategoricalFeatureCollection(car_cats, target=target)
car_proba = car_collection.convert2CondProba()

# %%
car_proba
# Out:
#         ps_car_01_cat  ps_car_02_cat  ps_car_03_cat  ps_car_04_cat  \
# 0            0.036976       0.033772       0.032707       0.033451
# 1            0.041581       0.033772       0.032707       0.033451
# 2            0.028770       0.033772       0.032707       0.033451
# 3            0.028770       0.033772       0.039538       0.033451
# 4            0.041581       0.033772       0.032707       0.033451
# 5            0.036976       0.049507       0.032707       0.033451
# 6            0.029763       0.033772       0.032707       0.033451
# 7            0.041581       0.033772       0.039538       0.033451
# 8            0.036976       0.033772       0.032707       0.033451
# 9            0.041581       0.049507       0.039538       0.048825
# 10           0.041581       0.033772       0.032707       0.050151
# 11           0.041581       0.049507       0.032707       0.033451
# 12           0.029763       0.033772       0.032707       0.033451
# ...

# %% [markdown]
# # PCA

# %% [markdown]
# ## Individially

# %%
y = np.array(target)
num_plot = 50000

class0_index = np.argwhere(y == 0).ravel()
class1_index = np.argwhere(y == 1).ravel()

print(class0_index)
print(class1_index)
# Out:
# [     0      1      2 ..., 595209 595210 595211]
# [     9     19     28 ..., 595099 595113 595158]

# %% [markdown]
# ### ind

# %%
pca1 = PCA()
Xpca_ind = pca1.fit_transform(np.array(ind_proba))

# %%
Xpca_ind.shape
# Out:
# (595212, 12)

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8), (ax9, ax10, ax11, ax12)) = plt.subplots(3, 4, figsize=(16, 12))
ax1.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 1], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax2.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 2], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax3.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 3], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax4.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 4], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax5.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 5], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax6.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 6], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax7.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 7], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax8.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 8], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax9.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 9], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax10.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 10], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax11.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 11], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
#ax12.scatter(Xpca_ind[num_plot], Xpca_ind[:num_plot], c=y[:num_plot], cmap=cm.bwr)

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8), (ax9, ax10, ax11, ax12)) = plt.subplots(3, 4, figsize=(16, 12))
ax1.scatter(Xpca_ind[:num_plot, 0], Xpca_ind[:num_plot, 1], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax2.scatter(Xpca_ind[:num_plot, 1], Xpca_ind[:num_plot, 2], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax3.scatter(Xpca_ind[:num_plot, 2], Xpca_ind[:num_plot, 3], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax4.scatter(Xpca_ind[:num_plot, 3], Xpca_ind[:num_plot, 4], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax5.scatter(Xpca_ind[:num_plot, 4], Xpca_ind[:num_plot, 5], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax6.scatter(Xpca_ind[:num_plot, 5], Xpca_ind[:num_plot, 6], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax7.scatter(Xpca_ind[:num_plot, 6], Xpca_ind[:num_plot, 7], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax8.scatter(Xpca_ind[:num_plot, 7], Xpca_ind[:num_plot, 8], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax9.scatter(Xpca_ind[:num_plot, 8], Xpca_ind[:num_plot, 9], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax10.scatter(Xpca_ind[:num_plot, 9], Xpca_ind[:num_plot, 10], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax11.scatter(Xpca_ind[:num_plot, 10], Xpca_ind[:num_plot, 11], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
#ax12.scatter(Xpca_ind[num_plot], Xpca_ind[:num_plot], c=y[:num_plot], cmap=cm.bwr)

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8), (ax9, ax10, ax11, ax12)) = plt.subplots(3, 4, figsize=(16, 12))
ax1.scatter(Xpca_ind[:num_plot, 0], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax2.scatter(Xpca_ind[:num_plot, 1], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax3.scatter(Xpca_ind[:num_plot, 2], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax4.scatter(Xpca_ind[:num_plot, 3], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax5.scatter(Xpca_ind[:num_plot, 4], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax6.scatter(Xpca_ind[:num_plot, 5], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax7.scatter(Xpca_ind[:num_plot, 6], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax8.scatter(Xpca_ind[:num_plot, 7], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax9.scatter(Xpca_ind[:num_plot, 8], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax10.scatter(Xpca_ind[:num_plot, 9], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax11.scatter(Xpca_ind[:num_plot, 10], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax12.scatter(Xpca_ind[:num_plot, 11], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)

# %%
num_bin = 18
fig = plt.figure(figsize=(16, 12))
for i in range(Xpca_ind.shape[1]):
    ax = fig.add_subplot(3, 4, i+1)
    
    x0 = Xpca_ind[class0_index, i]
    x1 = Xpca_ind[class1_index, i]
    
    ax.hist(x0, bins=num_bin, normed=1, color='blue', alpha=0.4)
    ax.hist(x1, bins=num_bin, normed=1, color='tomato', alpha=0.35)
    ax.set_ylim([0, 20])

# %%
ind_joint = psjp.JointProbability().fit_transform(ind_proba, target, label='ind_joint_proba')

# %%
X = np.array(ind_joint)
y = np.array(target)
num_plot = 50000

class0_index1 = np.argwhere(y == 0).ravel()
class1_index1 = np.argwhere(y == 1).ravel()

# %%
num_bin = 30
fig, ax = plt.subplots(1, 1, figsize=(4, 4))

x0 = X[class0_index]
x1 = X[class1_index]

ax.hist(x0, bins=num_bin, normed=1, color='blue', alpha=0.4)
ax.hist(x1, bins=num_bin, normed=1, color='tomato', alpha=0.35)
#ax.set_ylim([0, 20])
# Out:
# (array([  2.05604699e+01,   7.67265075e+00,   1.06397814e+00,
#           5.29196476e-01,   1.04722258e-01,   1.25666709e-01,
#           4.46814967e-02,   4.32851999e-02,   1.11703742e-02,
#           2.51333419e-02,   0.00000000e+00,   2.09444516e-02,
#           0.00000000e+00,   6.98148385e-03,   2.65296386e-02,
#           0.00000000e+00,   0.00000000e+00,   4.18889031e-03,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.67555612e-02,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   3.49074193e-02]),
#  array([ 0.00961538,  0.04262821,  0.07564103,  0.10865385,  0.14166667,
#          0.17467949,  0.20769231,  0.24070513,  0.27371795,  0.30673077,
#          0.33974359,  0.37275641,  0.40576923,  0.43878205,  0.47179487,
#          0.50480769,  0.53782051,  0.57083333,  0.60384615,  0.63685897,
# ...

# %% [markdown]
# ### car

# %%
pca2 = PCA()
Xpca_car = pca2.fit_transform(np.array(car_proba))

# %%
Xpca_car.shape
# Out:
# (595212, 11)

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8), (ax9, ax10, ax11, ax12)) = plt.subplots(3, 4, figsize=(16, 12))
ax1.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 1], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax2.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 2], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax3.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 3], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax4.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 4], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax5.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 5], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax6.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 6], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax7.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 7], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax8.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 8], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax9.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 9], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax10.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 10], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8), (ax9, ax10, ax11, ax12)) = plt.subplots(3, 4, figsize=(16, 12))
ax1.scatter(Xpca_car[:num_plot, 0], Xpca_car[:num_plot, 1], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax2.scatter(Xpca_car[:num_plot, 1], Xpca_car[:num_plot, 2], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax3.scatter(Xpca_car[:num_plot, 2], Xpca_car[:num_plot, 3], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax4.scatter(Xpca_car[:num_plot, 3], Xpca_car[:num_plot, 4], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax5.scatter(Xpca_car[:num_plot, 4], Xpca_car[:num_plot, 5], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax6.scatter(Xpca_car[:num_plot, 5], Xpca_car[:num_plot, 6], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax7.scatter(Xpca_car[:num_plot, 6], Xpca_car[:num_plot, 7], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax8.scatter(Xpca_car[:num_plot, 7], Xpca_car[:num_plot, 8], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax9.scatter(Xpca_car[:num_plot, 8], Xpca_car[:num_plot, 9], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax10.scatter(Xpca_car[:num_plot, 9], Xpca_car[:num_plot, 10], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
#ax11.scatter(Xpca_car[:num_plot, 10], Xpca_car[:num_plot, 11], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
#ax12.scatter(Xpca_car[num_plot], Xpca_car[:num_plot], c=y[:num_plot], cmap=cm.bwr)

# %%
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8), (ax9, ax10, ax11, ax12)) = plt.subplots(3, 4, figsize=(16, 12))
ax1.scatter(Xpca_car[:num_plot, 0], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax2.scatter(Xpca_car[:num_plot, 1], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax3.scatter(Xpca_car[:num_plot, 2], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax4.scatter(Xpca_car[:num_plot, 3], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax5.scatter(Xpca_car[:num_plot, 4], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax6.scatter(Xpca_car[:num_plot, 5], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax7.scatter(Xpca_car[:num_plot, 6], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax8.scatter(Xpca_car[:num_plot, 7], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax9.scatter(Xpca_car[:num_plot, 8], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax10.scatter(Xpca_car[:num_plot, 9], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
ax11.scatter(Xpca_car[:num_plot, 10], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)
#ax12.scatter(Xpca_car[:num_plot, 11], y[:num_plot], c=y[:num_plot], cmap=cm.bwr, alpha=0.15)

# %%
num_bin = 18
fig = plt.figure(figsize=(16, 12))
for i in range(Xpca_car.shape[1]):
    ax = fig.add_subplot(3, 4, i+1)
    
    x0 = Xpca_car[class0_index, i]
    x1 = Xpca_car[class1_index, i]
    
    ax.hist(x0, bins=num_bin, normed=1, color='blue', alpha=0.4)
    ax.hist(x1, bins=num_bin, normed=1, color='tomato', alpha=0.35)
    #ax.set_ylim([0, 20])

# %%
car_joint = psjp.JointProbability().fit_transform(car_proba, target, label='car_joint_proba')

# %%
X = np.array(car_joint)
y = np.array(target)
num_plot = 50000

class0_index1 = np.argwhere(y == 0).ravel()
class1_index1 = np.argwhere(y == 1).ravel()

# %%
num_bin = 30
fig, ax = plt.subplots(1, 1, figsize=(4, 4))

x0 = X[class0_index]
x1 = X[class1_index]

ax.hist(x0, bins=num_bin, normed=1, color='blue', alpha=0.4)
ax.hist(x1, bins=num_bin, normed=1, color='tomato', alpha=0.35)
#ax.set_ylim([0, 20])
# Out:
# (array([  9.97627970e+00,   8.52828920e+00,   3.51793665e+00,
#           1.55488913e+00,   1.30221964e+00,   7.45513804e-01,
#           1.62430382e-01,   6.52498115e-01,   1.44382562e-01,
#           7.64949918e-01,   6.94146931e-03,   1.18004978e-01,
#           2.91541711e-02,   0.00000000e+00,   9.73193998e-01,
#           0.00000000e+00,   0.00000000e+00,   2.22127018e-02,
#           0.00000000e+00,   7.21912809e-02,   0.00000000e+00,
#           0.00000000e+00,   8.32976318e-03,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.53822960e+00]),
#  array([ 0.00390625,  0.03710938,  0.0703125 ,  0.10351562,  0.13671875,
#          0.16992188,  0.203125  ,  0.23632812,  0.26953125,  0.30273438,
#          0.3359375 ,  0.36914062,  0.40234375,  0.43554688,  0.46875   ,
#          0.50195312,  0.53515625,  0.56835938,  0.6015625 ,  0.63476562,
# ...

# %% [markdown]
# ### any use in joint?

# %%
plt.figure(figsize=(6, 6))
plt.scatter(ind_joint, car_joint, c=y, cmap=cm.bwr, alpha=0.1)
plt.xlabel('ind_joint')
plt.ylabel('car_joint')
# Out:
# Text(0,0.5,'car_joint')

# %%
ind_joint_class0 = ind_joint[target == 0]
ind_joint_class1 = ind_joint[target == 1]
car_joint_class0 = car_joint[target == 0]
car_joint_class1 = car_joint[target == 1]

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,6))
ax.scatter(ind_joint_class0, car_joint_class0, color='skyblue', alpha=0.1)
ax.scatter(ind_joint_class1, car_joint_class1, color='tomato', alpha=0.05)
