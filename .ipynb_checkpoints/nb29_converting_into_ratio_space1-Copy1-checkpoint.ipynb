# %% [markdown]
# # Convert the binary and categorical feature space
# - Fuse categoricies for each feature into smaller number of categories based on conditional probabilities
# - Calculate how much edge each category value has over the bulk frequency of class1
# - Replace the category value with those ratios to inflate the differeces in conditional probabilities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
# %matplotlib inline

from importlib import reload
from matplotlib import cm
from imblearn.under_sampling import TomekLinks, RandomUnderSampler
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import (make_scorer, roc_auc_score, 
                             classification_report, 
                             precision_recall_curve,
                             roc_curve)
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from feature_processing import (create_contingency_table,
                                calculate_conditional_prob_bin,
                                encode_my_categorical_labels,
                                calculate_conditional_prob_cat,
                                estimate_cond_prob_density,
                                bin_myFeature)
import feature_analysis as fa
import porto_seguro as ps
# Out:
# /home/ryohayama/.local/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
def my_gini(y_true, y_probas):
    auc = roc_auc_score(y_true, y_probas[:, 1])
    gini = 2*auc - 1
    return gini

gini_scorer = make_scorer(my_gini, needs_proba=True, greater_is_better=True)

# %%
train = pd.read_csv('train.csv', header=0)

all_fs = train.columns[:-1]
binary_fs = sorted([f for f in all_fs if '_bin' in f])
categorical_fs = sorted([f for f in all_fs if '_cat' in f])
other_fs = sorted([f for f in all_fs
            if f not in binary_fs
            if f not in categorical_fs])

binaries = train[binary_fs]
categoricals = train[categorical_fs]
others = train[other_fs[1:-1]]

new_categoricals = ps.fuseCategoricalFeatures(categoricals)

bincats = pd.concat([binaries, new_categoricals], axis=1)
target = train.target

# %%
reload(ps)
# Out:
# <module 'porto_seguro' from '/home/ryohayama/python_current/porto_seguro/porto_seguro.py'>

# %%
bincat2probas = {}
for i, f in enumerate(bincats.columns):
    fvt = fa.FeatureVsTarget(bincats[f], target)
    bincat2probas[f] = (100*(fvt.calculate_deviation(mode='ratio')[0] - 1)[1]).to_dict()

# %%
bincat2probas['ps_car_03_cat']
# Out:
# {0: -10.263633402873607, 1: 8.478205372761982, 2: 32.513247918634434}

# %%
bincat_converted = pd.DataFrame()
for i, f in enumerate(bincats.columns):
    bincat_converted[f] = bincats[f].replace(bincat2probas[f])

# %%
bincat_converted.head(5)
# Out:
#    ps_calc_15_bin  ps_calc_16_bin  ps_calc_17_bin  ps_calc_18_bin  \
# 0        0.094183        0.246950       -0.078457       -0.180291
# 1        0.094183        0.246950       -0.078457       -0.180291
# 2        0.094183        0.246950       -0.078457       -0.180291
# 3        0.094183       -0.416609        0.097528       -0.180291
# 4        0.094183       -0.416609        0.097528        0.447503
#
#    ps_calc_19_bin  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ps_ind_09_bin  \
# 0        0.656528      14.095330      29.912302      -2.993119       2.019795
# 1       -1.224514      14.095330     -10.348293      15.266355       2.019795
# 2       -1.224514      14.095330     -10.348293      15.266355       2.019795
# 3        0.656528     -21.703055     -10.348293      -2.993119       2.019795
# 4       -1.224514     -21.703055     -10.348293      -2.993119       2.019795
#
#    ps_ind_10_bin      ...        ps_car_05_cat  ps_car_06_cat  ps_car_07_cat  \
# 0      -0.018024      ...             10.54458      -8.751671      -4.612259
# 1      -0.018024      ...            -13.00161      -8.751671      -4.612259
# 2      -0.018024      ...            -13.00161      -8.751671      -4.612259
# 3      -0.018024      ...             10.54458      -8.751671      -4.612259
# 4      -0.018024      ...            -13.00161      -8.751671      -4.612259
#
#    ps_car_08_cat  ps_car_09_cat  ps_car_10_cat  ps_car_11_cat  ps_ind_02_cat  \
# 0      23.282374      -3.261944       0.043887       8.665033       4.171961
# 1      -4.698558      -3.261944       0.043887     -27.910814      -1.983385
# 2      -4.698558      -3.261944       0.043887     -11.434986      11.888150
# 3      -4.698558      -3.261944       0.043887      24.500160      -1.983385
# 4      -4.698558      -3.261944       0.043887     -27.910814       4.171961
#
#    ps_ind_04_cat  ps_ind_05_cat
# 0       6.025876      -7.085708
# 1      -4.546991      -7.085708
# 2       6.025876      -7.085708
# 3      -4.546991      -7.085708
# 4       6.025876      -7.085708
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Take a look at continuous/ordinal features

# %%
others.loc[:, 'ps_car_12'] = bin_myFeature(others.loc[:, 'ps_car_12'], 0, 1.5, bins=20)[1]
others.loc[:, 'ps_car_13'] = bin_myFeature(others.loc[:, 'ps_car_13'], 0, 4, bins=50)[1]
others.loc[:, 'ps_car_13'] = bin_myFeature(others.loc[:, 'ps_car_13'], 0, 4, bins=50)[1]
others.loc[:, 'ps_car_14'] = bin_myFeature(others.loc[:, 'ps_car_14'], 0, 4, bins=40)[1]
others.loc[:, 'ps_reg_03'] = bin_myFeature(others.loc[:, 'ps_reg_03'], 0, 5, bins=50)[1]
# Out:
# /home/ryohayama/.local/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# <b>Conditional Probas and deviations</b>

# %%
for i, f in enumerate(others.columns):
    fvt = fa.FeatureVsTarget(others[f], target)
    print('==== %s ====' % f)
    print(fvt.contingency_table_)
    print(fvt.conditional_probas_)
    print(100*(fvt.calculate_deviation(mode='ratio')[0] - 1))
    print('\n')
# Out:
# ==== ps_calc_01 ====
# target          0     1
# ps_calc_01
# 0.0         57620  2160
# 0.1         57422  2082
# 0.2         57372  2141
# 0.3         57186  2191
# 0.4         57068  2180
# 0.5         57357  2255
# 0.6         57706  2131
# 0.7         57321  2224
# 0.8         57595  2115
# 0.9         56871  2215
# target         0         1
# 0.0     0.963868  0.036132
# 0.1     0.965011  0.034989
# 0.2     0.964025  0.035975
# 0.3     0.963100  0.036900
# 0.4     0.963206  0.036794
# 0.5     0.962172  0.037828
# 0.6     0.964387  0.035613
# 0.7     0.962650  0.037350
# 0.8     0.964579  0.035421
# 0.9     0.962512  0.037488
# target         0         1
# 0.0     0.032695 -0.864344
# 0.1     0.151343 -4.001023
# 0.2     0.049005 -1.295520
# 0.3    -0.046940  1.240940
# 0.4    -0.036010  0.951980
# 0.5    -0.143265  3.787463
# 0.6     0.086565 -2.288500
# 0.7    -0.093652  2.475849
# 0.8     0.106514 -2.815872
# 0.9    -0.107956  2.853999
#
#
# ==== ps_calc_02 ====
# target          0     1
# ps_calc_02
# 0.0         57534  2084
# 0.1         57255  2128
# 0.2         57191  2194
# 0.3         57421  2172
# 0.4         57569  2254
# 0.5         57909  2161
# 0.6         57272  2229
# 0.7         57339  2163
# 0.8         56938  2180
# 0.9         57090  2129
# target         0         1
# 0.0     0.965044  0.034956
# 0.1     0.964165  0.035835
# 0.2     0.963055  0.036945
# 0.3     0.963553  0.036447
# 0.4     0.962322  0.037678
# 0.5     0.964025  0.035975
# 5       0.099526   -2.631152
# 6       0.001815   -0.047984
# 7       0.080001   -2.114968
# 8      -0.201298    5.321657
# 9       0.118720   -3.138578
# 10     -0.059761    1.579887
# 11     -0.262390    6.936725
# 12     -0.127695    3.375828
# 13      0.026676   -0.705238
# 14     -0.822632   21.747686
# 15     -0.610296   16.134225
# 16      0.730189  -19.303792
# 17      3.782619 -100.000000
# 18      3.782619 -100.000000
# 19      3.782619 -100.000000
#
#
# ==== ps_calc_12 ====
# target           0     1
# ps_calc_12
# 0           135818  5183
# 1           195882  7398
# 2           140000  5321
# 3            67827  2524
# 4            24860   918
# 5             7019   271
# 6             1658    66
# 7              377    10
# 8               63     3
# 9               11     0
# 10               3     0
# target         0         1
# 0       0.963241  0.036759
# 1       0.963607  0.036393
# 2       0.963385  0.036615
# 3       0.964123  0.035877
# 4       0.964388  0.035612
# 5       0.962826  0.037174
# 6       0.961717  0.038283
# 7       0.974160  0.025840
# 8       0.954545  0.045455
# 9       1.000000  0.000000
# 10      1.000000  0.000000
# target         0           1
# 0      -0.032285    0.853520
# 1       0.005642   -0.149161
# 2      -0.017433    0.460867
# 3       0.059185   -1.564644
# 4       0.086737   -2.293039
# 5      -0.075418    1.993808
# 6      -0.190498    5.036131
# 7       1.100897  -29.104107
# 8      -0.934773   24.712321
# 9       3.782619 -100.000000
# 10      3.782619 -100.000000
#
#
# ==== ps_calc_13 ====
# target           0     1
# ps_calc_13
# 0            32401  1257
# 1            93153  3508
# 2           134274  5060
# 3           127597  4815
# 4            92233  3520
# 5            52559  2001
# 6            25384   942
# 7            10615   388
# 8             3734   148
# 9             1120    40
# 10             340    11
# 11              86     2
# 12              19     1
# 13               3     1
# target         0         1
# 0       0.962654  0.037346
# 1       0.963708  0.036292
# 2       0.963684  0.036316
# 3       0.963636  0.036364
# 4       0.963239  0.036761
# 5       0.963325  0.036675
# 6       0.964218  0.035782
# 7       0.964737  0.035263
# 8       0.961875  0.038125
# 9       0.965517  0.034483
# 10      0.968661  0.031339
# 11      0.977273  0.022727
# 12      0.950000  0.050000
# 13      0.750000  0.250000
# target          0           1
# 0       -0.093273    2.465819
# 1        0.016163   -0.427286
# 2        0.013689   -0.361896
# 3        0.008691   -0.229766
# 4       -0.032560    0.860779
# 5       -0.023632    0.624740
# 6        0.069057   -1.825642
# 7        0.122921   -3.249625
# 8       -0.174060    4.601576
# 9        0.203908   -5.390653
# 10       0.530172  -14.016007
# 11       1.423923  -37.643840
# 12      -1.406512   37.183553
# 13     -22.163036  585.917765
#
#
# ==== ps_calc_14 ====
# target          0     1
# ps_calc_14
# 0             298    12
# 1            2317    81
# 2            8620   322
# 3           22038   787
# 4           41062  1534
# 5           61643  2386
# 6           77911  2986
# 7           83542  3131
# 8           79242  2935
# 9           65953  2534
# 10          50165  1884
# 11          34029  1312
# 12          21435   792
# 13          12402   481
# 14           6663   271
# 15           3403   133
# 16           1597    69
# 17            709    26
# 18            296     9
# 19            123     8
# 20             46     1
# 21             18     0
# 22              5     0
# 23              1     0
# target         0         1
# 0       0.961290  0.038710
# 1       0.966222  0.033778
# 1.5         12041   628
# 1.6          8183   427
# 1.7          5246   279
# 1.8          4181   223
# 1.9          1889   123
# 2.0           913    56
# 2.1           490    34
# 2.2           234     9
# 2.3           220    17
# 2.4            99     6
# 2.5            49     3
# 2.6            59     2
# 2.7             8     1
# 2.8            16     2
# 2.9            20     1
# 3.1             1     1
# 3.4             4     0
# 3.7             1     0
# 4.0             3     0
# 5.0        104712  3060
# target         0         1
# 0.0     1.000000  0.000000
# 0.1     1.000000  0.000000
# 0.2     0.976285  0.023715
# 0.3     0.974007  0.025993
# 0.4     0.970702  0.029298
# 0.5     0.970742  0.029258
# 0.6     0.966402  0.033598
# 0.7     0.964700  0.035300
# 0.8     0.960626  0.039374
# 0.9     0.956788  0.043212
# 1.0     0.957753  0.042247
# 1.1     0.954810  0.045190
# 1.2     0.954898  0.045102
# 1.3     0.954883  0.045117
# 1.4     0.954503  0.045497
# 1.5     0.950430  0.049570
# 1.6     0.950407  0.049593
# 1.7     0.949502  0.050498
# 1.8     0.949364  0.050636
# 1.9     0.938867  0.061133
# 2.0     0.942208  0.057792
# 2.1     0.935115  0.064885
# 2.2     0.962963  0.037037
# 2.3     0.928270  0.071730
# 2.4     0.942857  0.057143
# 2.5     0.942308  0.057692
# 2.6     0.967213  0.032787
# 2.7     0.888889  0.111111
# 2.8     0.888889  0.111111
# 2.9     0.952381  0.047619
# 3.1     0.500000  0.500000
# 3.4     1.000000  0.000000
# 3.7     1.000000  0.000000
# 4.0     1.000000  0.000000
# 5.0     0.971607  0.028393
# target          0            1
# 0.0      3.782619  -100.000000
# 0.1      3.782619  -100.000000
# 0.2      1.321371   -34.932702
# 0.3      1.084998   -28.683784
# 0.4      0.741996   -19.615925
# 0.5      0.746148   -19.725708
# 0.6      0.295727    -7.818036
# 0.7      0.119110    -3.148884
# 0.8     -0.303704     8.028939
# 0.9     -0.702044    18.559740
# 1.0     -0.601846    15.910824
# 1.1     -0.907351    23.987385
# 1.2     -0.898223    23.746061
# 1.3     -0.899715    23.785507
# 1.4     -0.939132    24.827574
# 1.5     -1.361866    36.003270
# 1.6     -1.364324    36.068240
# 1.7     -1.458169    38.549181
# 1.8     -1.472496    38.927940
# 1.9     -2.561945    67.729394
# 2.0     -2.215138    58.560969
# 2.1     -2.951368    78.024458
# 2.2     -0.061182     1.617447
# 2.3     -3.661704    96.803409
# 2.4     -2.147817    56.781203
# 2.5     -2.204840    58.288715
# 2.6      0.379910   -10.043572
# 2.7     -7.748783   204.852340
# 2.8     -7.748783   204.852340
# 2.9     -1.159411    30.651003
# 3.1    -48.108691  1271.835531
# 3.4      3.782619  -100.000000
# 3.7      3.782619  -100.000000
# 4.0      3.782619  -100.000000
# 5.0      0.835890   -22.098194

# %%
bincat2probas = {}
for i, f in enumerate(bincats.columns):
    fvt = fa.FeatureVsTarget(bincats[f], target)
    bincat2probas[f] = (100*(fvt.calculate_deviation(mode='ratio')[0] - 1)[1]).to_dict()

# %%
bincat2probas['ps_car_03_cat']
# Out:
# {0: -10.263633402873607, 1: 8.478205372761982, 2: 32.513247918634434}

# %%
bincat_converted = pd.DataFrame()
for i, f in enumerate(bincats.columns):
    bincat_converted[f] = bincats[f].replace(bincat2probas[f])

# %%
bincat_converted
# Out:
#         ps_calc_15_bin  ps_calc_16_bin  ps_calc_17_bin  ps_calc_18_bin
# 595196       0.043887       8.665033      -1.983385      -4.546991
# 595197       0.043887     -11.434986      -1.983385       6.025876
# 595198       0.043887       8.665033      -1.983385       6.025876
# 595199       0.043887      24.500160      -1.983385       6.025876
# 595200       0.043887     -11.434986      -1.983385      -4.546991
# 595201       0.043887     -27.910814       4.171961       6.025876
# 595202       0.043887     -11.434986      -1.983385      -4.546991
# 595203       0.043887      47.480624       4.171961       6.025876
# 595204       0.043887     -11.434986       4.171961       6.025876
# 595205       0.043887     -11.434986       4.171961       6.025876
# 595206       0.043887      24.500160      -1.983385      -4.546991
# 595207       0.043887       8.665033      -1.983385      -4.546991
# 595208       0.043887      64.663539      -1.983385      -4.546991
# 595209       0.043887       8.665033      -1.983385      -4.546991
# 595210       0.043887       8.665033       4.171961       6.025876
# 595211       0.043887       8.665033      -1.983385      -4.546991
#
#         ps_ind_05_cat
# 0           -7.085708
# 1           -7.085708
# 2           -7.085708
# 3           -7.085708
# 4           -7.085708
# 5           -7.085708
# 6           -7.085708
# 7           -7.085708
# 8           -7.085708
# 9           -7.085708
# 10          -7.085708
# 11          -7.085708
# 12          -7.085708
# 13          -7.085708
# 14          -7.085708
# 15          -7.085708
# 16          -7.085708
# 17          38.855046
# 18          -7.085708
# 19          -7.085708
# 20          -7.085708
# 21          38.855046
# 22          17.971524
# 23          -7.085708
# 24          -7.085708
# 25          -7.085708
# 26          -7.085708
# 27          -7.085708
# 28          38.855046
# 29          -7.085708
# ...               ...
# 595182      -7.085708
# 595183      -7.085708
# 595184      -7.085708
# 595185      -7.085708
# 595186      -7.085708
# 595187      38.855046
# 595188      -7.085708
# 595189      -7.085708
# 595190      -7.085708
# 595191      -7.085708
# 595192      -7.085708
# 595193     119.647438
# 595194      -7.085708
# 595195      -7.085708
# 595196      -7.085708
# 595197      -7.085708
# 595198      -7.085708
# 595199      -7.085708
# 595200      17.971524
# 595201      -7.085708
# 595202      -7.085708
# 595203      -7.085708
# 595204      -7.085708
# 595205      -7.085708
# 595206      -7.085708
# 595207      -7.085708
# 595208      -7.085708
# 595209      -7.085708
# 595210      -7.085708
# 595211      -7.085708
#
# [595212 rows x 30 columns]

# %%
select_other_fs = ['ps_calc_05', 'ps_calc_07', 'ps_calc_13', 'ps_calc_14',
                   'ps_car_12', 'ps_car_13', 'ps_ind_03', 'ps_ind_14', 'ps_reg_02', 'ps_reg_03']
select_others = train[select_other_fs]
select_others.loc[:, 'ps_car_12'] = bin_myFeature(select_others.loc[:, 'ps_car_12'], 0, 1.5, bins=20)[1]
select_others.loc[:, 'ps_car_13'] = bin_myFeature(select_others.loc[:, 'ps_car_13'], 0, 4, bins=50)[1]
select_others.loc[:, 'ps_reg_03'] = bin_myFeature(select_others.loc[:, 'ps_reg_03'], 0, 5, bins=50)[1]
# Out:
# /home/ryohayama/.local/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
others2probas = {}
for i, f in enumerate(select_others.columns):
    fvt = fa.FeatureVsTarget(select_others[f], target)
    others2probas[f] = (100*(fvt.calculate_deviation(mode='ratio')[0] - 1)[1]).to_dict()

# %%
others_converted = pd.DataFrame()
for i, f in enumerate(select_others.columns):
    others_converted[f] = select_others[f].replace(others2probas[f])

# %%
converted = pd.concat([bincat_converted, others_converted], axis=1)

# %%
converted.columns
# Out:
# Index(['ps_calc_15_bin', 'ps_calc_16_bin', 'ps_calc_17_bin', 'ps_calc_18_bin',
#        'ps_calc_19_bin', 'ps_ind_06_bin', 'ps_ind_07_bin', 'ps_ind_08_bin',
#        'ps_ind_09_bin', 'ps_ind_10_bin', 'ps_ind_11_bin', 'ps_ind_12_bin',
#        'ps_ind_13_bin', 'ps_ind_16_bin', 'ps_ind_17_bin', 'ps_ind_18_bin',
#        'ps_car_01_cat', 'ps_car_02_cat', 'ps_car_03_cat', 'ps_car_04_cat',
#        'ps_car_05_cat', 'ps_car_06_cat', 'ps_car_07_cat', 'ps_car_08_cat',
#        'ps_car_09_cat', 'ps_car_10_cat', 'ps_car_11_cat', 'ps_ind_02_cat',
#        'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_calc_05', 'ps_calc_07',
#        'ps_calc_13', 'ps_calc_14', 'ps_car_12', 'ps_car_13', 'ps_ind_03',
#        'ps_ind_14', 'ps_reg_02', 'ps_reg_03'],
#       dtype='object')

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
'target' in converted.iloc[:, :-1].columns
# Out:
# False

# %%
pca = PCA()
X = np.array(converted.iloc[:, :-1])
y = train.target

Xpca = pca.fit_transform(X)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(12, 8))
ax1.scatter(Xpca[:, 0], Xpca[:, 1], c=y, cmap=cm.Blues, s=10)
ax2.scatter(Xpca[:, 0], Xpca[:, 2], c=y, cmap=cm.Blues, s=10)
ax3.scatter(Xpca[:, 0], Xpca[:, 3], c=y, cmap=cm.Blues, s=10)
ax4.scatter(Xpca[:, 1], Xpca[:, 2], c=y, cmap=cm.Blues, s=10)
ax5.scatter(Xpca[:, 1], Xpca[:, 3], c=y, cmap=cm.Blues, s=10)
ax6.scatter(Xpca[:, 2], Xpca[:, 3], c=y, cmap=cm.Blues, s=10)

# %%
pca.explained_variance_ratio_
# Out:
# array([  2.69778808e-01,   9.33393804e-02,   7.58280900e-02,
#          6.35052414e-02,   5.52598467e-02,   5.06270751e-02,
#          4.47971369e-02,   4.17832159e-02,   3.65624910e-02,
#          3.52757930e-02,   3.28993385e-02,   3.06268845e-02,
#          2.64427867e-02,   2.52235699e-02,   2.35142774e-02,
#          1.92234617e-02,   1.83057443e-02,   1.76248022e-02,
#          1.08626671e-02,   9.11184410e-03,   6.16424744e-03,
#          5.14582963e-03,   4.28217678e-03,   9.42660504e-04,
#          7.18792507e-04,   5.35601008e-04,   4.37556508e-04,
#          3.74949554e-04,   2.61977881e-04,   1.56843453e-04,
#          1.25427131e-04,   1.13688594e-04,   7.12559791e-05,
#          4.05042685e-05,   1.45496511e-05,   1.14102613e-05,
#          8.99229228e-06,   1.08214021e-06,   1.01033666e-27])

# %%
plt.bar(range(Xpca.shape[1]), pca.explained_variance_ratio_)
# Out:
# <Container object of 39 artists>

# %%
# %%time
fig = plt.figure(figsize=(8, 4))
ax21 = fig.add_subplot(1, 2, 1)
ax22 = fig.add_subplot(1, 2, 2)

neutral_line = np.linspace(0, 1, 10)
ax21.plot(neutral_line, neutral_line, lw=1, ls='--')
ax22.plot(neutral_line, 1- neutral_line, lw=1, ls='--')

ginis_xgb = []

for i in range(5):

    rstate = None
    X_train, X_test, y_train, y_test = train_test_split(Xpca[:, :20], y, test_size=0.1, random_state=rstate)

    num_class1 = np.sum(y_train)
    num_class1_to_resample = 2 * num_class1
    num_class0_to_resample = int(1 * num_class1_to_resample)

    # First, randomly undersample the majority
    rus = RandomUnderSampler(ratio={0: num_class0_to_resample , 1: num_class1})
    X_tlrus, y_tlrus = rus.fit_sample(X_train, y_train)

    # Then use SMOTE to oversample the minority
    smote = SMOTE(ratio={0: num_class0_to_resample , 1: num_class1_to_resample}, n_jobs=8)
    X_res, y_res = smote.fit_sample(X_tlrus, y_tlrus)

    # GradientBoost
    clf = RandomForestClassifier(n_estimators=200, max_depth=10, n_jobs=8)
    clf.fit(X_res, y_res)

    y_pred2 = clf.predict(X_test)
    y_proba2 = clf.predict_proba(X_test)
    ginis_xgb.append(my_gini(y_test, y_proba2))
    report2 = classification_report(y_test, y_pred2, digits=4,
                                   labels=None, target_names=None)

    precision2, recall2, _ = precision_recall_curve(y_test, y_proba2[:, 1], pos_label=1)
    fpr2, tpr2, _ = roc_curve(y_test, y_proba2[:, 1], pos_label=1)
    ax21.plot(fpr2, tpr2)
    ax21.set_xlabel('False Positive Rate')
    ax21.set_ylabel('True Positive Rate')
    ax21.set_title('GradientBoost ROC')
    ax22.plot(recall2, precision2)
    ax22.set_xlabel('Recall')
    ax22.set_ylabel('Precision')
    ax22.set_title('GradientBoost Precision-Recall')

plt.tight_layout()

print('Gini=%.3f+/-%.3f, Best=%.3f' % (np.mean(ginis_xgb), np.std(ginis_xgb), np.max(ginis_xgb)))
# Out:
# Gini=0.260+/-0.008, Best=0.267
# CPU times: user 6min 17s, sys: 695 ms, total: 6min 18s
# Wall time: 53 s

# %%
from sklearn.linear_model import LogisticRegression

# %%
# %%time
fig = plt.figure(figsize=(8, 4))
ax21 = fig.add_subplot(1, 2, 1)
ax22 = fig.add_subplot(1, 2, 2)

neutral_line = np.linspace(0, 1, 10)
ax21.plot(neutral_line, neutral_line, lw=1, ls='--')
ax22.plot(neutral_line, 1- neutral_line, lw=1, ls='--')

ginis_xgb = []

for i in range(5):

    rstate = None
    X_train, X_test, y_train, y_test = train_test_split(Xpca, y, test_size=0.1, random_state=rstate)

    num_class1 = np.sum(y_train)
    num_class1_to_resample = 2 * num_class1
    num_class0_to_resample = int(1 * num_class1_to_resample)

    # First, randomly undersample the majority
    rus = RandomUnderSampler(ratio={0: num_class0_to_resample , 1: num_class1})
    X_tlrus, y_tlrus = rus.fit_sample(X_train, y_train)

    # Then use SMOTE to oversample the minority
    smote = SMOTE(ratio={0: num_class0_to_resample , 1: num_class1_to_resample}, n_jobs=8)
    X_res, y_res = smote.fit_sample(X_tlrus, y_tlrus)

    # GradientBoost
    clf = LogisticRegression(C=1e4, penalty='l1')
    clf.fit(X_res, y_res)

    y_pred2 = clf.predict(X_test)
    y_proba2 = clf.predict_proba(X_test)
    ginis_xgb.append(my_gini(y_test, y_proba2))
    report2 = classification_report(y_test, y_pred2, digits=4,
                                   labels=None, target_names=None)

    precision2, recall2, _ = precision_recall_curve(y_test, y_proba2[:, 1], pos_label=1)
    fpr2, tpr2, _ = roc_curve(y_test, y_proba2[:, 1], pos_label=1)
    ax21.plot(fpr2, tpr2)
    ax21.set_xlabel('False Positive Rate')
    ax21.set_ylabel('True Positive Rate')
    ax21.set_title('GradientBoost ROC')
    ax22.plot(recall2, precision2)
    ax22.set_xlabel('Recall')
    ax22.set_ylabel('Precision')
    ax22.set_title('GradientBoost Precision-Recall')

plt.tight_layout()

print('Gini=%.3f+/-%.3f, Best=%.3f' % (np.mean(ginis_xgb), np.std(ginis_xgb), np.max(ginis_xgb)))
# Out:
# Gini=0.249+/-0.010, Best=0.268
# CPU times: user 1min 55s, sys: 2.86 s, total: 1min 58s
# Wall time: 18.3 s

# %%
# %%time
fig = plt.figure(figsize=(8, 4))
ax21 = fig.add_subplot(1, 2, 1)
ax22 = fig.add_subplot(1, 2, 2)

neutral_line = np.linspace(0, 1, 10)
ax21.plot(neutral_line, neutral_line, lw=1, ls='--')
ax22.plot(neutral_line, 1- neutral_line, lw=1, ls='--')

ginis_xgb = []

for i in range(5):

    rstate = None
    X_train, X_test, y_train, y_test = train_test_split(Xpca, y, test_size=0.1, random_state=rstate)

    num_class1 = np.sum(y_train)
    num_class1_to_resample = 2 * num_class1
    num_class0_to_resample = int(1 * num_class1_to_resample)

    # First, randomly undersample the majority
    rus = RandomUnderSampler(ratio={0: num_class0_to_resample , 1: num_class1})
    X_tlrus, y_tlrus = rus.fit_sample(X_train, y_train)

    # Then use SMOTE to oversample the minority
    smote = SMOTE(ratio={0: num_class0_to_resample , 1: num_class1_to_resample}, n_jobs=8)
    X_res, y_res = smote.fit_sample(X_tlrus, y_tlrus)

    # GradientBoost
    clf = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=1, gamma=9, learning_rate=0.05, max_delta_step=0,
       max_depth=11, min_child_weight=4, missing=None, n_estimators=200,
       n_jobs=8, nthread=None, objective='binary:logistic', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=True, subsample=0.85)
    clf.fit(X_res, y_res)

    y_pred2 = clf.predict(X_test)
    y_proba2 = clf.predict_proba(X_test)
    ginis_xgb.append(my_gini(y_test, y_proba2))
    report2 = classification_report(y_test, y_pred2, digits=4,
                                   labels=None, target_names=None)

    precision2, recall2, _ = precision_recall_curve(y_test, y_proba2[:, 1], pos_label=1)
    fpr2, tpr2, _ = roc_curve(y_test, y_proba2[:, 1], pos_label=1)
    ax21.plot(fpr2, tpr2)
    ax21.set_xlabel('False Positive Rate')
    ax21.set_ylabel('True Positive Rate')
    ax21.set_title('GradientBoost ROC')
    ax22.plot(recall2, precision2)
    ax22.set_xlabel('Recall')
    ax22.set_ylabel('Precision')
    ax22.set_title('GradientBoost Precision-Recall')

plt.tight_layout()

print('Gini=%.3f+/-%.3f, Best=%.3f' % (np.mean(ginis_xgb), np.std(ginis_xgb), np.max(ginis_xgb)))
# Out:
# Gini=0.239+/-0.012, Best=0.254
# CPU times: user 16min 10s, sys: 1.07 s, total: 16min 11s
# Wall time: 2min 8s
